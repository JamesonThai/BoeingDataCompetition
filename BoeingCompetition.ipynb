# %%
import pandas as pd

# %%
airline_delay_causes_df = pd.read_csv('bdc/airline_delay_causes.csv')
flight_sample_df = pd.read_csv('bdc/flight sample.csv') 
airport_id_df = pd.read_csv('bdc/L_AIRPORT_ID.csv')
cancellation_df = pd.read_csv('bdc/L_CANCELLATION.csv')
carriers_df = pd.read_csv('bdc/L_UNIQUE_CARRIERS.csv')
variable_df = pd.read_csv('bdc/VariableDescription.csv')
md_df = pd.read_csv('bdc/monthly data/133080461_T_ONTIME_REPORTING 2.csv')
md_df2 = pd.read_csv('bdc/monthly data/133080461_T_ONTIME_REPORTING 3.csv')
# Note md_df3 HAS A COLUMN MIX TYPE
md_df3 = pd.read_csv('bdc/monthly data/133080461_T_ONTIME_REPORTING 6.csv')
md_df4 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 4.csv')
md_df5 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 5.csv')
md_df6 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 7.csv')
md_df7 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 8.csv')
md_df8 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 9.csv')
md_df9 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 10.csv')
md_df10 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 11.csv')
md_df11 = pd.read_csv('bdc/monthly data/133081407_T_ONTIME_REPORTING 12.csv')
md_df12 = pd.read_csv('bdc/monthly data/560702993_T_ONTIME_REPORTING 1.csv')
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
airline_delay_causes_df.head()
# Out:
#    year   month carrier carrier_name airport  \
# 0  2018       1      MQ    Envoy Air     BIS
# 1  2018       1      MQ    Envoy Air     BNA
# 2  2018       1      MQ    Envoy Air     BOI
# 3  2018       1      MQ    Envoy Air     BPT
# 4  2018       1      MQ    Envoy Air     BUF
#
#                                      airport_name  arr_flights  arr_del15  \
# 0         Bismarck/Mandan, ND: Bismarck Municipal          5.0        3.0
# 1          Nashville, TN: Nashville International        110.0       21.0
# 2                   Boise, ID: Boise Air Terminal         32.0        8.0
# 3  Beaumont/Port Arthur, TX: Jack Brooks Regional         63.0       11.0
# 4      Buffalo, NY: Buffalo Niagara International         31.0       12.0
#
#    carrier_ct   weather_ct     ...       late_aircraft_ct  arr_cancelled  \
# 0        1.00         0.06     ...                   0.00            0.0
# 1        7.17         1.16     ...                   5.92            3.0
# 2        0.22         0.35     ...                   1.82            0.0
# 3        1.75         1.08     ...                   5.19            3.0
# 4        0.82         3.00     ...                   1.55            0.0
#
#    arr_diverted   arr_delay   carrier_delay  weather_delay  nas_delay  \
# 0           0.0       104.0            54.0            1.0       49.0
# 1           0.0       897.0           344.0           37.0      226.0
# 2           0.0       353.0             9.0           18.0      233.0
# 3           0.0       657.0            83.0           34.0      130.0
# 4           0.0       484.0            27.0          136.0      207.0
#
#    security_delay  late_aircraft_delay  Unnamed: 21
# 0             0.0                  0.0          NaN
# 1             0.0                290.0          NaN
# 2             0.0                 93.0          NaN
# 3             0.0                410.0          NaN
# 4             0.0                114.0          NaN
#
# [5 rows x 22 columns]

# %%
flight_sample_df.head()
# Out:
#    ACTUAL_ELAPSED_TIME  AIR_TIME  ARR_DELAY  ARR_TIME CANCELLATION_CODE  \
# 0                 86.0      68.0       -7.0    1043.0               NaN
# 1                 75.0      59.0       -9.0    1516.0               NaN
# 2                122.0     101.0       -3.0    1101.0               NaN
# 3                 64.0      50.0       -1.0     734.0               NaN
# 4                 68.0      56.0       22.0    1932.0               NaN
#
#    CANCELLED  CARRIER_DELAY  CRS_DEP_TIME  CRS_ELAPSED_TIME  DAY_OF_MONTH  \
# 0          0            NaN           820                90            10
# 1          0            NaN          1402                83            28
# 2          0            NaN           900               124            20
# 3          0            NaN           630                65             5
# 4          0            5.0          1755                75            16
#
#    ...   ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  SECURITY_DELAY  TAXI_IN  \
# 0  ...               15016              1501606.0             NaN      7.0
# 1  ...               14321              1432105.0             NaN      6.0
# 2  ...               13204              1320402.0             NaN      8.0
# 3  ...               12992              1299206.0             NaN      4.0
# 4  ...               10800              1080003.0             0.0      2.0
#
#    TAXI_OUT  Unnamed: 32  WEATHER_DELAY  WHEELS_OFF WHEELS_ON  YEAR
# 0      11.0          NaN            NaN       828.0    1036.0  2018
# 1      10.0          NaN            NaN      1411.0    1510.0  2018
# 2      13.0          NaN            NaN       912.0    1053.0  2018
# 3      10.0          NaN            NaN       640.0     730.0  2018
# 4      10.0          NaN            0.0      1834.0    1930.0  2018
#
# [5 rows x 33 columns]

# %%
airport_id_df.head()
# Out:
#     Code                                    Description
# 0  10001         Afognak Lake, AK: Afognak Lake Airport
# 1  10003  Granite Mountain, AK: Bear Creek Mining Strip
# 2  10004                       Lik, AK: Lik Mining Camp
# 3  10005         Little Squaw, AK: Little Squaw Airport
# 4  10006                     Kizhuyak, AK: Kizhuyak Bay

# %%
cancellation_df.head()
# Out:
#   Code          Description
# 0    A              Carrier
# 1    B              Weather
# 2    C  National Air System
# 3    D             Security

# %%
carriers_df.head()
# Out:
#   Code                    Description
# 0  02Q                  Titan Airways
# 1  04Q             Tradewind Aviation
# 2  05Q            Comlux Aviation, AG
# 3  06Q  Master Top Linhas Aereas Ltd.
# 4  07Q            Flair Airlines Ltd.

# %%
variable_df.head()
# Out:
#       SYS_FIELD_NAME                                         FIELD_DESC
# 0               YEAR                                               Year
# 1       DAY_OF_MONTH                                       Day of Month
# 2        DAY_OF_WEEK                                        Day of Week
# 3            FL_DATE                             Flight Date (yyyymmdd)
# 4  OP_UNIQUE_CARRIER  Unique Carrier Code. When the same code has be...

# %%
md_df.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            4  2018-02-01                F9
# 1  2018             1            4  2018-02-01                F9
# 2  2018             1            4  2018-02-01                F9
# 3  2018             1            4  2018-02-01                F9
# 4  2018             1            4  2018-02-01                F9
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               1104              12889                1288903
# 1                408              12892                1289208
# 2               1456              12889                1288903
# 3               1680              12889                1288903
# 4                680              11292                1129202
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            13303              1330303     ...         235.0      1.0
# 1            11292              1129202     ...         108.0      1.0
# 2            10397              1039707     ...         195.0      1.0
# 3            13204              1320402     ...         239.0      1.0
# 4            13204              1320402     ...         174.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    2174.0               9            NaN            NaN        NaN
# 1     862.0               4            NaN            NaN        NaN
# 2    1747.0               7            NaN            NaN        NaN
# 3    2039.0               9            NaN            NaN        NaN
# 4    1546.0               7            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df2.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            4  2018-03-01                F9
# 1  2018             1            4  2018-03-01                F9
# 2  2018             1            4  2018-03-01                F9
# 3  2018             1            4  2018-03-01                F9
# 4  2018             1            4  2018-03-01                F9
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               1680              12889                1288903
# 1                681              13204                1320402
# 2                681              11292                1129202
# 3                144              14747                1474703
# 4                122              11292                1129202
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            13204              1320402     ...         272.0      1.0
# 1            11292              1129202     ...         222.0      1.0
# 2            14747              1474703     ...         143.0      1.0
# 3            11292              1129202     ...         128.0      1.0
# 4            11298              1129806     ...          83.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    2039.0               9           20.0            0.0       32.0
# 1    1546.0               7            4.0            0.0        0.0
# 2    1024.0               5            0.0            0.0        0.0
# 3    1024.0               5            0.0            0.0        0.0
# 4     641.0               3            0.0            0.0        0.0
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             0.0                 91.0         NaN
# 1             0.0                111.0         NaN
# 2             0.0                 87.0         NaN
# 3             0.0                 53.0         NaN
# 4             0.0                 25.0         NaN
#
# [5 rows x 33 columns]

# %%
md_df3.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            5  2018-06-01                9E
# 1  2018             3            7  2018-06-03                9E
# 2  2018             4            1  2018-06-04                9E
# 3  2018             5            2  2018-06-05                9E
# 4  2018             6            3  2018-06-06                9E
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               5212              12953                1295304
# 1               5212              12953                1295304
# 2               5212              12953                1295304
# 3               5212              12953                1295304
# 4               5212              12953                1295304
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            14492              1449202     ...          59.0      1.0
# 1            14492              1449202     ...          70.0      1.0
# 2            14492              1449202     ...          70.0      1.0
# 3            14492              1449202     ...          72.0      1.0
# 4            14492              1449202     ...          62.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0     431.0               2            0.0            0.0        0.0
# 1     431.0               2            NaN            NaN        NaN
# 2     431.0               2            0.0            0.0        3.0
# 3     431.0               2            NaN            NaN        NaN
# 4     431.0               2           36.0            0.0        0.0
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             0.0                 80.0         NaN
# 1             NaN                  NaN         NaN
# 2             0.0                 14.0         NaN
# 3             NaN                  NaN         NaN
# 4             0.0                 14.0         NaN
#
# [5 rows x 33 columns]

# %%
md_df3 = md_df3[sorted(md_df3.columns)]
# md_df3.head()
print(md_df3.columns)
print(md_df.columns)
# Out:
# Index(['ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'ARR_DELAY', 'ARR_TIME',
#        'CANCELLATION_CODE', 'CANCELLED', 'CARRIER_DELAY', 'CRS_DEP_TIME',
#        'CRS_ELAPSED_TIME', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'DEP_TIME',
#        'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID', 'DISTANCE', 'DISTANCE_GROUP',
#        'DIVERTED', 'FLIGHTS', 'FL_DATE', 'LATE_AIRCRAFT_DELAY', 'NAS_DELAY',
#        'OP_CARRIER_FL_NUM', 'OP_UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'SECURITY_DELAY', 'TAXI_IN', 'TAXI_OUT',
#        'Unnamed: 32', 'WEATHER_DELAY', 'WHEELS_OFF', 'WHEELS_ON', 'YEAR'],
#       dtype='object')

# %%
md_df4.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018            26            4  2018-04-26                UA
# 1  2018            26            4  2018-04-26                UA
# 2  2018            26            4  2018-04-26                UA
# 3  2018            26            4  2018-04-26                UA
# 4  2018            26            4  2018-04-26                UA
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               2268              11433                1143302
# 1               2268              11618                1161802
# 2               2266              14771                1477104
# 3               2265              15304                1530402
# 4               2264              14771                1477104
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            11618              1161802     ...          73.0      1.0
# 1            14492              1449202     ...          74.0      1.0
# 2            11603              1160302     ...          61.0      1.0
# 3            12264              1226402     ...         108.0      1.0
# 4            10721              1072102     ...         316.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0     488.0               2           33.0            0.0        3.0
# 1     416.0               2            NaN            NaN        NaN
# 2     451.0               2            NaN            NaN        NaN
# 3     811.0               4            NaN            NaN        NaN
# 4    2704.0              11            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             0.0                 84.0         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df5.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            2  2018-05-01                F9
# 1  2018             1            2  2018-05-01                F9
# 2  2018             1            2  2018-05-01                F9
# 3  2018             1            2  2018-05-01                F9
# 4  2018             1            2  2018-05-01                F9
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               1274              14107                1410702
# 1               1194              13930                1393006
# 2               1194              12391                1239102
# 3               1588              12889                1288903
# 4               1228              15304                1530402
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            13930              1393006     ...         173.0      1.0
# 1            12391              1239102     ...         101.0      1.0
# 2            14843              1484306     ...         217.0      1.0
# 3            15304              1530402     ...         217.0      1.0
# 4            10792              1079206     ...         146.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    1440.0               6            0.0            0.0       82.0
# 1     773.0               4            0.0            0.0        4.0
# 2    1597.0               7            NaN            NaN        NaN
# 3    1984.0               8            NaN            NaN        NaN
# 4    1053.0               5            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             0.0                  0.0         NaN
# 1             0.0                 73.0         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df6.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            7  2018-07-01                9E
# 1  2018             2            1  2018-07-02                9E
# 2  2018             3            2  2018-07-03                9E
# 3  2018             4            3  2018-07-04                9E
# 4  2018             5            4  2018-07-05                9E
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               3280              10397                1039707
# 1               3280              10397                1039707
# 2               3280              10397                1039707
# 3               3280              10397                1039707
# 4               3280              10397                1039707
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            12007              1200704     ...          43.0      1.0
# 1            12007              1200704     ...          47.0      1.0
# 2            12007              1200704     ...          41.0      1.0
# 3            12007              1200704     ...          41.0      1.0
# 4            12007              1200704     ...          42.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0     241.0               1            NaN            NaN        NaN
# 1     241.0               1            NaN            NaN        NaN
# 2     241.0               1            NaN            NaN        NaN
# 3     241.0               1            NaN            NaN        NaN
# 4     241.0               1            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df7.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018            12            7  2018-08-12                AA
# 1  2018            13            1  2018-08-13                AA
# 2  2018            14            2  2018-08-14                AA
# 3  2018            15            3  2018-08-15                AA
# 4  2018            16            4  2018-08-16                AA
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               1586              11996                1199603
# 1               1586              11996                1199603
# 2               1586              11996                1199603
# 3               1586              11996                1199603
# 4               1586              11996                1199603
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            11298              1129806     ...         125.0      1.0
# 1            11298              1129806     ...         125.0      1.0
# 2            11298              1129806     ...         123.0      1.0
# 3            11298              1129806     ...         127.0      1.0
# 4            11298              1129806     ...         118.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0     862.0               4            NaN            NaN        NaN
# 1     862.0               4            NaN            NaN        NaN
# 2     862.0               4            NaN            NaN        NaN
# 3     862.0               4            NaN            NaN        NaN
# 4     862.0               4            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df8.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018            23            7  2018-09-23                UA
# 1  2018            23            7  2018-09-23                UA
# 2  2018            23            7  2018-09-23                UA
# 3  2018            23            7  2018-09-23                UA
# 4  2018            23            7  2018-09-23                UA
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               1585              13198                1319801
# 1               1584              11618                1161802
# 2               1583              12889                1288903
# 3               1582              15304                1530402
# 4               1581              11618                1161802
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            14771              1477104     ...         201.0      1.0
# 1            14771              1477104     ...         333.0      1.0
# 2            11618              1161802     ...         244.0      1.0
# 3            11618              1161802     ...         136.0      1.0
# 4            12889              1288903     ...         288.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    1499.0               6            NaN            NaN        NaN
# 1    2565.0              11           57.0            0.0       35.0
# 2    2227.0               9            NaN            NaN        NaN
# 3     997.0               4            NaN            NaN        NaN
# 4    2227.0               9           16.0            0.0        0.0
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             0.0                  0.0         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             0.0                  0.0         NaN
#
# [5 rows x 33 columns]

# %%
md_df9.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            1  2018-10-01                WN
# 1  2018             1            1  2018-10-01                WN
# 2  2018             1            1  2018-10-01                WN
# 3  2018             1            1  2018-10-01                WN
# 4  2018             1            1  2018-10-01                WN
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0                802              10140                1014005
# 1               3744              10140                1014005
# 2               1019              10140                1014005
# 3               1499              10140                1014005
# 4               3635              10140                1014005
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            10821              1082106     ...         197.0      1.0
# 1            10821              1082106     ...         191.0      1.0
# 2            11259              1125903     ...          80.0      1.0
# 3            11259              1125903     ...          81.0      1.0
# 4            11259              1125903     ...          80.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    1670.0               7            NaN            NaN        NaN
# 1    1670.0               7            NaN            NaN        NaN
# 2     580.0               3            NaN            NaN        NaN
# 3     580.0               3            NaN            NaN        NaN
# 4     580.0               3            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df10.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             1            4  2018-11-01                9E
# 1  2018             2            5  2018-11-02                9E
# 2  2018             3            6  2018-11-03                9E
# 3  2018             4            7  2018-11-04                9E
# 4  2018             5            1  2018-11-05                9E
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               3280              10397                1039707
# 1               3280              10397                1039707
# 2               3280              10397                1039707
# 3               3280              10397                1039707
# 4               3280              10397                1039707
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            11617              1161708     ...          63.0      1.0
# 1            11617              1161708     ...          61.0      1.0
# 2            11617              1161708     ...          61.0      1.0
# 3            12197              1219702     ...         103.0      1.0
# 4            12197              1219702     ...         104.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0     433.0               2            NaN            NaN        NaN
# 1     433.0               2            NaN            NaN        NaN
# 2     433.0               2            NaN            NaN        NaN
# 3     780.0               4            NaN            NaN        NaN
# 4     780.0               4            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df11.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018             6            4  2018-12-06                DL
# 1  2018             6            4  2018-12-06                DL
# 2  2018             6            4  2018-12-06                DL
# 3  2018             6            4  2018-12-06                DL
# 4  2018             6            4  2018-12-06                DL
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0               2454              14908                1490803
# 1               2455              10423                1042302
# 2               2456              12478                1247805
# 3               2457              10397                1039707
# 4               2457              10529                1052906
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID     ...      AIR_TIME  FLIGHTS  \
# 0            10397              1039707     ...         200.0      1.0
# 1            10397              1039707     ...          97.0      1.0
# 2            11697              1169706     ...         152.0      1.0
# 3            10529              1052906     ...         108.0      1.0
# 4            10397              1039707     ...         132.0      1.0
#
#    DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0    1919.0               8            NaN            NaN        NaN
# 1     813.0               4            NaN            NaN        NaN
# 2    1069.0               5            NaN            NaN        NaN
# 3     859.0               4            NaN            NaN        NaN
# 4     859.0               4            NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY Unnamed: 32
# 0             NaN                  NaN         NaN
# 1             NaN                  NaN         NaN
# 2             NaN                  NaN         NaN
# 3             NaN                  NaN         NaN
# 4             NaN                  NaN         NaN
#
# [5 rows x 33 columns]

# %%
md_df12.head()
# Out:
#    YEAR  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE OP_UNIQUE_CARRIER  \
# 0  2018            27            6  2018-01-27                UA
# 1  2018            27            6  2018-01-27                UA
# 2  2018            27            6  2018-01-27                UA
# 3  2018            27            6  2018-01-27                UA
# 4  2018            27            6  2018-01-27                UA
#
#    OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  CRS_DEP_TIME  \
# 0                369              11697            12266           615
# 1                368              14747            14771           618
# 2                367              11278            12266           830
# 3                366              12892            13930           650
# 4                365              12451            11618          1824
#
#    DEP_TIME     ...       ACTUAL_ELAPSED_TIME  AIR_TIME  FLIGHTS  DISTANCE  \
# 0     602.0     ...                     174.0     148.0      1.0     966.0
# 1     614.0     ...                     119.0      98.0      1.0     679.0
# 2     828.0     ...                     220.0     190.0      1.0    1208.0
# 3     641.0     ...                     241.0     212.0      1.0    1744.0
# 4    1810.0     ...                     131.0     112.0      1.0     820.0
#
#    CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY SECURITY_DELAY  \
# 0            NaN            NaN        NaN            NaN
# 1            NaN            NaN        NaN            NaN
# 2            NaN            NaN        NaN            NaN
# 3            NaN            NaN        NaN            NaN
# 4            NaN            NaN        NaN            NaN
#
#    LATE_AIRCRAFT_DELAY  Unnamed: 29
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
#
# [5 rows x 30 columns]
